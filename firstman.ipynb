# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'D:\niHal\python_adv\indian_food.csv')
df['state'] = df['state'].apply(lambda x: x if x!="-1" else "Unknown State")
df['flavor_profile'] = df['flavor_profile'].apply(lambda x: x if x!="-1" else "Unknown Flavor")

# %%
nf = pd.DataFrame(df, columns = ['diet','state'])

# %%
i= df[df['diet']=='non vegetarian']
j = pd.DataFrame(i,columns = ['state'])
x = j.state.value_counts().plot(kind='bar');

# %%
a= df['ingredients']
b = pd.DataFrame(a)
num = np.array(b)
#most used ingredient in indian food
last=[]
for n in range(0,255):
    last = last + num[n][0].split(',')
    
#last = num[254][0].split(',') + num[253][0].split(',')
ing = pd.DataFrame(last)

ingre = ing.value_counts().head(20)#.plot(kind='bar');
ingre.plot(kind='bar');
